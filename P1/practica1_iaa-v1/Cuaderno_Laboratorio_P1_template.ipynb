# %% [markdown]
# # Cuaderno de Laboratorio — Práctica 1: La Física del Aprendizaje Automático
#
# **Alumno/a:** Juan Luis Prieto Panadero y Alberto Álvarez Mejías
# **Fecha:**  /02/2026
#
# Este cuaderno está pensado para generar las gráficas y escribir el análisis. La entrega final debe ser **PDF**.

# %%
include("optimizacion_energia.jl")
# Si quieres el runner automático:
# include("experimentos_practica1.jl")
# Out:
# Figura guardada en outputs/
# Épocas ejecutadas: 100

# %% [markdown]
# ## Tarea 1 — α
# 1. Ajusta `α` para provocar los cuatro comportamientos (slow/opt/osc/fail).
# 2. Inserta/pega las figuras guardadas en `outputs/`.
# 3. Responde las preguntas de análisis.

# %% [markdown]
# ## Tarea 2 — batch
# Con tu `αopt`, compara batch completo vs mini-batch vs estocástico.

# %% [markdown]
# ## Reto — criterio de parada
# Activa `tol = 1e-5` en `optimizacion_energia.jl` o usa `minibatch_gd(...; tol=1e-5)` y reporta la combinación que para antes con error aceptable.

# %% [markdown]
# ## Conclusiones
# Escribe aquí tus conclusiones (8–12 líneas).
